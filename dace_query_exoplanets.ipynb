# %%
import numpy as np
#import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib as mpl
from astropy.io import fits
from astropy.io.fits import getheader
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
#import mpyfit
from astropy.io import fits
from scipy.signal import argrelextrema
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
import csv
import pickle
import math as m
import os
import pandas as pd
from scipy.special import erfinv, erf, erfc, erfcinv
from mpfit import mpfit
import datetime
from astropy.time import Time
from astropy.convolution import convolve, Box1DKernel

#globally change font size for plots
plt.rcParams['font.size'] =17
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
# Out:
# /Users/zdebeurs/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from dace_query.sun import Sun

# %%
Sun.download_public_release_timeseries(output_directory = '/Users/zdebeurs/Documents/Github/rv_net/',output_filename='public_release_timeseries.rdb')
# Out:
# 2023-07-18 10:24:33,895 - INFO - Downloading file on location : /Users/zdebeurs/Documents/Github/rv_net/public_release_timeseries.rdb
#  Download : 5 MB
# 2023-07-18 10:24:37,570 - INFO - File downloaded on location : /Users/zdebeurs/Documents/Github/rv_net/public_release_timeseries.rdb
#  Download : 6 MB
# Download done

# %%
#pd.read_csv("public_release_timeseries.rdb")

values = Sun.get_timeseries()

# %%
values['date_bjd']
# Out:
# array([57232.87283724, 57232.87659043, 57232.88036531, ...,
#        58262.94888224, 58262.95267454, 58262.95645348])

# %%
from dace_query.spectroscopy import Spectroscopy
import numpy as np

# Retrieve radial velocity timeseries for the HD40307 target
result = Spectroscopy.get_timeseries(target='HD212657', sorted_by_instrument=False, output_format='numpy')
result
# Out:
# {'texp': array([ 900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900., 1800., 1800.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900., 1800., 1800.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
#          900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,  900.,
# ...

# %%
result.keys()
# Out:
# dict_keys(['texp', 'bispan', 'bispan_err', 'drift_noise', 'rjd', 'cal_therror', 'fwhm', 'fwhm_err', 'rv', 'rv_err', 'berv', 'ccf_noise', 'rhk', 'rhk_err', 'contrast', 'contrast_err', 'cal_thfile', 'spectroFluxSn50', 'protm08', 'protm08_err', 'caindex', 'caindex_err', 'pub_reference', 'pub_bibcode', 'drs_qc', 'haindex', 'haindex_err', 'protn84', 'protn84_err', 'naindex', 'naindex_err', 'snca2', 'ins_name', 'mask', 'ins_mode', 'public', 'spectroFluxSn20', 'drs_version', 'sindex', 'sindex_err', 'drift_used', 'ccf_asym', 'ccf_asym_err', 'date_night', 'raw_file', 'prog_id', 'th_ar', 'th_ar1', 'th_ar2'])
