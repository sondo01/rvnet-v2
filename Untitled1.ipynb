# %%
# DACE import
import dace_query as Dace

# list the different DACE modules
help(Dace)
# Out:
# Help on package dace_query:
#
# NAME
#     dace_query
#
# PACKAGE CONTENTS
#     __version__
#     astrometry (package)
#     atmosphericSpectroscopy (package)
#     catalog (package)
#     cheops (package)
#     dace
#     exoplanet (package)
#     imaging (package)
#     lossy (package)
#     monitoring (package)
#     opacity (package)
#     opendata (package)
#     photometry (package)
#     population (package)
#     spectroscopy (package)
#     sun (package)
#     target (package)
#     tess (package)
#
# DATA
#     Dace = <dace_query.dace.DaceClass object>
#     __title__ = 'dace-query'
#
# VERSION
#     2.0.0
#
# FILE
#     /Users/sondo/AI/venv-3.11/lib/python3.11/site-packages/dace_query/__init__.py
